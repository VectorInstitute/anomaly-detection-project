# %% [markdown]
# # <center> Anomaly Detection in Images
#
# In this notebook, we will delve into the exciting realm of anomaly detection in images. Our focus will be on two powerful methods: DRAEM and CFA. We'll explore how these approaches tackle the challenge of detecting anomalies, leveraging the MVTEC dataset for evaluation. DRAEM excels in generating abnormal samples to improve detection performance, while CFA maximizes robustness by utilizing pretrained networks for feature extraction.
#
# ## Outline
# * MVTEC Dataset
# * Anomaly Generation based methods: Draem
#     * Implementation using Anomalib
#     * Results
# * Pretrain network methods: CFA
#     * Implementation using Anomalib
#     * Results
# * Gradio and Hugging Face

# %% [markdown]
# ## Dataset: MVTec AD
#
# The [MVTEC dataset](https://www.mvtec.com/company/research/datasets/mvtec-ad) is a widely used benchmark for evaluating anomaly detection methods, specifically in the context of industrial inspection. It consists of more than 5000 high-resolution images across 15 different object and texture categories. Each category includes a training set of defect-free images and a test set comprising images with various types of defects, as well as defect-free images for comparison. If the dataset is not already present in the root datasets directory, you can rely on the anomalib library to automatically install it.
#
# Some of the classes/categories included in the MVTEC dataset are:
#
# * Bottle
# * Cable
# * Capsule
# * Carpet
# * Grid
# * Hazelnut
# * Leather
# * Metal-Nut
# * Pill
# * Screw
# * Tile
# * Toothbrush
# * Transistor
# * Wood
# * Zipper
#
# By importing the MVtec AD dataset using the specific datamodule provided by anomalib, we can easily access the images and associated labels for anomaly detection tasks in Jupyter Notebook.

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1g2TC2Z83ciiivXbWz27oXJyUA94KySBI)

# %% [markdown]
# ## Anomalib
# [Anomalib](https://github.com/openvinotoolkit/anomalib): Anomalib is a deep learning library that aims to collect state-of-the-art anomaly detection algorithms for benchmarking on both public and private datasets. Anomalib provides several ready-to-use implementations of anomaly detection algorithms described in the recent literature, as well as a set of tools that facilitate the development and implementation of custom models. The library has a strong focus on image-based anomaly detection, where the goal of the algorithm is to identify anomalous images, or anomalous pixel regions within images in a dataset.
#
# The library supports [`MVTec AD`](https://www.mvtec.com/company/research/datasets/mvtec-ad) (CC BY-NC-SA 4.0) for **benchmarking**.

# %% [markdown]
# ## DRÆM- Model
#
# In this part, we'll be covering [DRÆM–A discriminatively trained reconstruction embedding for surface anomaly detection](https://openaccess.thecvf.com/content/ICCV2021/papers/Zavrtanik_DRAEM_-_A_Discriminatively_Trained_Reconstruction_Embedding_for_Surface_Anomaly_ICCV_2021_paper.pdf).
#
# DRÆM learns a joint representation of an anomalous image and its anomaly-free reconstruction, while simultaneously learning a decision boundary between normal and anomalous examples.
#
# * The reconstructive sub-network is trained to implicitly detect and reconstruct the anomalies with semantically plausible anomaly-free content, while keeping the non-anomalous regions of the input image unchanged.
#
# * Simultaneously, the discriminative sub-network learns a joint reconstruction-anomaly embedding and produces ac- curate anomaly segmentation maps from the concatenated reconstructed and original appearance.
#
# * Anomalous training examples are created by a conceptually simple process that simulates anomalies on anomaly-free images.
#
# * This anomaly generation method provides an arbitrary amount of anomalous samples as well as pixel-perfect anomaly segmentation maps which can be used for training the proposed method without real anomalous samples.
#
# * **reconstructive sub-network** is formulated as an encoder-decoder architecture that converts the local patterns of an input image into patterns closer to the distribution of normal samples.
#
# $$
# L_{r e c}\left(I, I_r\right)=\lambda L_{S S I M}\left(I, I_r\right)+l_2\left(I, I_r\right),
# $$
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1hTdOvGs-D_L6xc99DrSPJ3Vf74fStQuO" width="700" aligh="center">
# </center>
#
# * **Discriminative sub-network** The sub-network input $I_c$ is deﬁned as the channel-wise concatenation of the reconstructive subnetwork output $I_r$ and the input image $I$. Due to the normality-restoring property of the reconstructive subnetwork, the joint appearance of $I$ and $I_r$ differs signiﬁcantly in anomalous images, providing the information necessary for anomaly segmentation.
#
# * the discriminative sub-network learns the appropriate distance measure automatically. The network outputs an anomaly score map $M_o$ of the same size as $I$. Focal Loss (Lseg) is applied on the discriminative sub-network output to increase robustness towards accurate segmentation of hard examples.
#
# * Considering both the segmentation and the reconstructive objectives of the two sub-networks, the total loss used in training DRÆM is
#
# $$
# L\left(I, I_r, M_a, M\right)=L_{r e c}\left(I, I_r\right)+L_{s e g}\left(M_a, M\right)
# $$
#
# where $Ma$ and $M$ are the ground truth and the output anomaly segmentation masks, respectively.

# %% [markdown]
# ## DRÆM- Simulated Anomaly Generation
#
# * A noise image is generated by a Perlin noise generator to capture a variety of anomaly shapes (The below figure $P$) and binarized by a threshod sampled uniformly at random (The below figure, $M_a$) into an anomaly map $M_a$. The anomaly texture source image $A$ is sampled from an anomaly source image dataset which is unrelated to the input image distribution. Random augmentation sampling is then applied by a set of 3 random augmentation functions sampled from the set: {posterize, sharpness, solarize, equalize, brightness change, color change, auto-contrast}. The augmented texture image $A$ is masked with the anomaly map Ma and blended with $I$ to create anomalies that are just-out-of- distribution, and thus help tighten the decision boundary in the trained network. The augmented training image $I_a$ is therefore deﬁned as
#
# $$
# I_a=\bar{M}_a \odot I+(1-\beta)\left(M_a \odot I\right)+\beta\left(M_a \odot A\right)
# $$
#
# where $\bar{M}_a$ is the inverse of $M_a, \odot$ is the element-wise multiplication operation and $\beta$ is the opacity parameter in blending. This parameter is sampled uniformly from an in-
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1hWdIeJ1hgx7lVS0lfK1IdhA0rnKXGAxn" width="500" aligh="center">
# </center>

# %% [markdown]
# ## DRÆM- Simulated Anomlay Generation Samples
#
# The below image shows some example of simulated anomalies
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1h4xaMThjs_LZDm69zHEmWaprFIYG6NuH" width="600" aligh="center">
# </center>

# %% [markdown]
# ## DRÆM- Localization and Detection
#
# The output of the discriminative sub-network is a pixel-level anomaly detection mask $M_o$, which can be interpreted in a straightforward way for the image-level anomaly score estimation,
#
#
# First, $M_o$ is smoothed by a mean filter convolution layer to aggregate the local anomaly response information. The final image-level anomaly score $\eta$ is computed by taking the maximum value of the smoothed anomaly score map:
# $$
# \eta=\max \left(M_o * f_{s_f \times s_f}\right),
# $$
# where $f_{s_f \times s_f}$ is a mean filter of size $s_f \times s_f$ and $*$ is the convolution operator.

# %% [markdown]
# ## DRAEM - Metrics
#
# * AUROC : ROC is a probability curve and AUC represents the degree or measure of separability. It tells how much the model is capable of distinguishing between classes. Higher the AUC, the better the model is at predicting 0 classes as 0 and 1 classes as 1
#
# * I-AUROC: Image level AUROC
# * P-AUROC: Pixel Level AUROC

# %% [markdown]
# ## DRÆM- Result
#
# * Results for the task of anomaly localization on the MVTec dataset (AUROC - Pixel Level).
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1KTiPj5sq6rAeuCoFW_t7d8lXsfLqESAC" width="400" aligh="center">
# </center>
#
# * Results for the task of anomaly localization on the MVTec dataset (AUROC - Image Level).
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1fC2HKKUTKzyRtTqS486nx-K4qkziyYYw" width="400" aligh="center">
# </center>
#
# 1: GANomaly: Semi-supervised anomaly detection via adversarial training
#
# 4: Uninformed students:Student-teacher anomaly detection with discriminative latent embeddings
#
# 11: Padim:a patch distribution modeling framework for anomaly detection and localization
#
# 20: Modeling the distribution of normal data in pre-trained deep features for anomaly detection
#
# 26: Anomaly detection neural network with dual auto-encoders gan and its industrial inspection applications
#
# 31: Reconstruction by inpainting for visual anomaly detection

# %% [markdown]
# ## DRÆM- Result
#
# * Qualitative examples. The original image, the anomaly map overlay, the anomaly map and the ground truth map are shown.
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1hmlyZByduj-bIW0uV9rH1RKhV88dUovF" width="800" aligh="center">
# </center>

# %% [markdown]
# ## Further reading
#
# * [Fake It Until You Make It : Towards Accurate Near-Distribution Novelty Detection](https://openreview.net/forum?id=QWQM0ZwZdRS)
#
# * [G2D: Generate to Detect](https://openaccess.thecvf.com/content/WACV2021/papers/Pourreza_G2D_Generate_to_Detect_Anomaly_WACV_2021_paper.pdf)

# %% [markdown]
# ## Installing Anomalib

# %% [markdown]
# Installation can be done in two ways:
# * (i) install via PyPI.
# * (ii) installing from sourc, both of which are shown below:

# %% [markdown]
# ### I. Install via PyPI

# %%
# Option - I: Uncomment the next line if you want to install via pip.
#%pip install anomalib
#%pip install openvino
#%pip install openvino-dev
#%pip install openvino-telemetry
#%pip install openvino-colab
#%pip install gitpython
#%pip install onnx

# %% [markdown]
# ### II. Install from Source
# This option would initially download anomalib repository from github and manually install `anomalib` from source, which is shown below:

# %%
# Option - II: Uncomment the next three lines if you want to install from the source.
# !git clone https://github.com/openvinotoolkit/anomalib.git
# %cd anomalib
# %pip install .

# %% [markdown]
#  Now let's verify the working directory. This is to access the datasets and configs when the notebook is run from different platforms such as local or Google Colab or Vector Jupyter hub.

# %%
## Import libraries
from __future__ import annotations
import os
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
from typing import Any
from IPython.display import Image
from anomalib.data import InferenceDataset, TaskType
from git.repo import Repo
from anomalib.data.utils import InputNormalizationMethod, get_transforms
from anomalib.post_processing import (
    NormalizationMethod,
    ThresholdMethod,
    superimpose_anomaly_map,
)
from torch.utils.data import DataLoader


#set the path for main folder
current_directory = Path.cwd()
root_directory = current_directory / "anomalib"

#change directory to the project folder
os.chdir(root_directory)
print(root_directory)
# Out:
# /ssd003/home/mpourreza/Projects/AD_bootcamp/MVTec/anomalib

# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from pytorch_lightning import Trainer
from torchvision.transforms import ToPILImage

from anomalib.config import get_configurable_parameters
from anomalib.data import get_datamodule
from anomalib.data.utils import read_image
from anomalib.deploy import OpenVINOInferencer,TorchInferencer
from anomalib.models import get_model
from anomalib.pre_processing.transforms import Denormalize
from anomalib.utils.callbacks import LoadModelCallback, get_callbacks
# Out:
# To use wandb logger install it using `pip install wandb`

# %%
MODEL = "draem" # choosing the model 
CONFIG_PATH = root_directory / f"src/anomalib/models/{MODEL}/config.yaml" # detailed configs loaded from this file
print(CONFIG_PATH)
# Out:
# /ssd003/home/mpourreza/Projects/AD_bootcamp/MVTec/anomalib/src/anomalib/models/draem/config.yaml

# %%
# pass the config file to model, callbacks and datamodule
config = get_configurable_parameters(config_path=CONFIG_PATH)
print(config.dataset.category)
# config.dataset.category = "bottle" # Choosing the classes from MVTec classes
# Out:
# bottle

# %%
datamodule = get_datamodule(config)
datamodule.prepare_data()  # Downloads the dataset if it's not in the specified `root` directory
datamodule.setup()  # Create train/val/test/prediction sets.

i, data = next(enumerate(datamodule.val_dataloader()))
print(data.keys())
# Out:
# dict_keys(['image_path', 'label', 'image', 'mask_path', 'mask'])

# %% [markdown]
# Let's check the shapes of the input images and masks.

# %%
print(data["image"].shape, data["mask"].shape)
# Out:
# torch.Size([32, 3, 256, 256]) torch.Size([32, 256, 256])

# %%
def show_image_and_mask(sample: dict[str, Any], index: int) -> Image:
    """
    Display an image and its corresponding mask side by side.

    Args:
        sample (dict[str, Any]): A dictionary containing the image and mask arrays.
        index (int): The index of the specific image and mask to display.

    Returns:
        Image: The concatenated image and mask as a PIL Image object.
    """
    img = ToPILImage()(Denormalize()(sample["image"][index].clone()))
    msk = ToPILImage()(sample["mask"][index]).convert("RGB")

    return Image.fromarray(np.hstack((np.array(img), np.array(msk))))


# Visualize an image with a mask
show_image_and_mask(data, index=0)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
# Set the export-mode to Torch to create the Torch IR model.
config.optimization.export_mode = "torch"

# Get the model and callbacks / Download the wide_resnet50 from pytorh hub
model = get_model(config)
callbacks = get_callbacks(config)

# %% [markdown]
# ## Training the model

# %%
# start training
trainer = Trainer(**config.trainer, callbacks=callbacks)
trainer.fit(model=model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                  | Type                     | Params
# -------------------------------------------------------------------
# 0 | image_threshold       | AnomalyScoreThreshold    | 0
# 1 | pixel_threshold       | AnomalyScoreThreshold    | 0
# 2 | model                 | DraemModel               | 97.4 M
# 3 | loss                  | DraemLoss                | 0
# 4 | image_metrics         | AnomalibMetricCollection | 0
# 5 | pixel_metrics         | AnomalibMetricCollection | 0
# 6 | normalization_metrics | MinMax                   | 0
# -------------------------------------------------------------------
# 97.4 M    Trainable params
# 0         Non-trainable params
# 97.4 M    Total params
# 389.691   Total estimated model params size (MB)
# Epoch 0:  91%|█████████ | 31/34 [01:05<00:06,  2.12s/it, loss=1.06, v_num=0, train_loss_step=1.050]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0:  94%|█████████▍| 32/34 [01:11<00:04,  2.24s/it, loss=1.06, v_num=0, train_loss_step=1.050]
# Epoch 0:  97%|█████████▋| 33/34 [01:13<00:02,  2.22s/it, loss=1.06, v_num=0, train_loss_step=1.050]
# Epoch 0: 100%|██████████| 34/34 [01:15<00:00,  2.23s/it, loss=1.06, v_num=0, train_loss_step=1.050, pixel_F1Score=0.177, pixel_AUROC=0.652]
# Epoch 1:  91%|█████████ | 31/34 [01:06<00:06,  2.13s/it, loss=1.02, v_num=0, train_loss_step=1.020, pixel_F1Score=0.177, pixel_AUROC=0.652, train_loss_epoch=1.140]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:  94%|█████████▍| 32/34 [01:11<00:04,  2.25s/it, loss=1.02, v_num=0, train_loss_step=1.020, pixel_F1Score=0.177, pixel_AUROC=0.652, train_loss_epoch=1.140]
# Epoch 1:  97%|█████████▋| 33/34 [01:13<00:02,  2.24s/it, loss=1.02, v_num=0, train_loss_step=1.020, pixel_F1Score=0.177, pixel_AUROC=0.652, train_loss_epoch=1.140]
# Epoch 1: 100%|██████████| 34/34 [01:16<00:00,  2.24s/it, loss=1.02, v_num=0, train_loss_step=1.020, pixel_F1Score=0.293, pixel_AUROC=0.618, train_loss_epoch=1.140]
# Epoch 2:  91%|█████████ | 31/34 [01:08<00:06,  2.19s/it, loss=1.01, v_num=0, train_loss_step=0.992, pixel_F1Score=0.293, pixel_AUROC=0.618, train_loss_epoch=1.020]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  94%|█████████▍| 32/34 [01:13<00:04,  2.31s/it, loss=1.01, v_num=0, train_loss_step=0.992, pixel_F1Score=0.293, pixel_AUROC=0.618, train_loss_epoch=1.020]
# Epoch 2:  97%|█████████▋| 33/34 [01:15<00:02,  2.30s/it, loss=1.01, v_num=0, train_loss_step=0.992, pixel_F1Score=0.293, pixel_AUROC=0.618, train_loss_epoch=1.020]
# Epoch 2: 100%|██████████| 34/34 [01:18<00:00,  2.30s/it, loss=1.01, v_num=0, train_loss_step=0.992, pixel_F1Score=0.236, pixel_AUROC=0.499, train_loss_epoch=1.020]
# Epoch 3:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.994, v_num=0, train_loss_step=1.000, pixel_F1Score=0.236, pixel_AUROC=0.499, train_loss_epoch=1.010]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.994, v_num=0, train_loss_step=1.000, pixel_F1Score=0.236, pixel_AUROC=0.499, train_loss_epoch=1.010]
# Epoch 3:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.994, v_num=0, train_loss_step=1.000, pixel_F1Score=0.236, pixel_AUROC=0.499, train_loss_epoch=1.010]
# Epoch 3: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, loss=0.994, v_num=0, train_loss_step=1.000, pixel_F1Score=0.165, pixel_AUROC=0.450, train_loss_epoch=1.010]
# Epoch 4:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.985, v_num=0, train_loss_step=0.965, pixel_F1Score=0.165, pixel_AUROC=0.450, train_loss_epoch=0.998]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 4:  94%|█████████▍| 32/34 [01:14<00:04,  2.33s/it, loss=0.985, v_num=0, train_loss_step=0.965, pixel_F1Score=0.165, pixel_AUROC=0.450, train_loss_epoch=0.998]
# Epoch 4:  97%|█████████▋| 33/34 [01:16<00:02,  2.32s/it, loss=0.985, v_num=0, train_loss_step=0.965, pixel_F1Score=0.165, pixel_AUROC=0.450, train_loss_epoch=0.998]
# Epoch 4: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.985, v_num=0, train_loss_step=0.965, pixel_F1Score=0.221, pixel_AUROC=0.599, train_loss_epoch=0.998]
# Epoch 5:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.961, v_num=0, train_loss_step=0.970, pixel_F1Score=0.221, pixel_AUROC=0.599, train_loss_epoch=0.986]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5:  94%|█████████▍| 32/34 [01:14<00:04,  2.33s/it, loss=0.961, v_num=0, train_loss_step=0.970, pixel_F1Score=0.221, pixel_AUROC=0.599, train_loss_epoch=0.986]
# Epoch 5:  97%|█████████▋| 33/34 [01:16<00:02,  2.32s/it, loss=0.961, v_num=0, train_loss_step=0.970, pixel_F1Score=0.221, pixel_AUROC=0.599, train_loss_epoch=0.986]
# Epoch 5: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.961, v_num=0, train_loss_step=0.970, pixel_F1Score=0.252, pixel_AUROC=0.606, train_loss_epoch=0.986]
# Epoch 6:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.946, v_num=0, train_loss_step=0.930, pixel_F1Score=0.252, pixel_AUROC=0.606, train_loss_epoch=0.965]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 6:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.946, v_num=0, train_loss_step=0.930, pixel_F1Score=0.252, pixel_AUROC=0.606, train_loss_epoch=0.965]
# Epoch 6:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.946, v_num=0, train_loss_step=0.930, pixel_F1Score=0.252, pixel_AUROC=0.606, train_loss_epoch=0.965]
# Epoch 6: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, loss=0.946, v_num=0, train_loss_step=0.930, pixel_F1Score=0.197, pixel_AUROC=0.521, train_loss_epoch=0.965]
# Epoch 7:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.923, v_num=0, train_loss_step=0.921, pixel_F1Score=0.197, pixel_AUROC=0.521, train_loss_epoch=0.951]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.923, v_num=0, train_loss_step=0.921, pixel_F1Score=0.197, pixel_AUROC=0.521, train_loss_epoch=0.951]
# Epoch 7:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.923, v_num=0, train_loss_step=0.921, pixel_F1Score=0.197, pixel_AUROC=0.521, train_loss_epoch=0.951]
# Epoch 7: 100%|██████████| 34/34 [01:19<00:00,  2.33s/it, loss=0.923, v_num=0, train_loss_step=0.921, pixel_F1Score=0.225, pixel_AUROC=0.530, train_loss_epoch=0.951]
# Epoch 8:  91%|█████████ | 31/34 [01:08<00:06,  2.20s/it, loss=0.9, v_num=0, train_loss_step=0.913, pixel_F1Score=0.225, pixel_AUROC=0.530, train_loss_epoch=0.926]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 8:  94%|█████████▍| 32/34 [01:14<00:04,  2.32s/it, loss=0.9, v_num=0, train_loss_step=0.913, pixel_F1Score=0.225, pixel_AUROC=0.530, train_loss_epoch=0.926]
# Epoch 8:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.9, v_num=0, train_loss_step=0.913, pixel_F1Score=0.225, pixel_AUROC=0.530, train_loss_epoch=0.926]
# Epoch 8: 100%|██████████| 34/34 [01:18<00:00,  2.31s/it, loss=0.9, v_num=0, train_loss_step=0.913, pixel_F1Score=0.213, pixel_AUROC=0.594, train_loss_epoch=0.926]
# Epoch 9:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.867, v_num=0, train_loss_step=0.911, pixel_F1Score=0.213, pixel_AUROC=0.594, train_loss_epoch=0.903]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 9:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.867, v_num=0, train_loss_step=0.911, pixel_F1Score=0.213, pixel_AUROC=0.594, train_loss_epoch=0.903]
# Epoch 9:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.867, v_num=0, train_loss_step=0.911, pixel_F1Score=0.213, pixel_AUROC=0.594, train_loss_epoch=0.903]
# Epoch 9: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.867, v_num=0, train_loss_step=0.911, pixel_F1Score=0.217, pixel_AUROC=0.546, train_loss_epoch=0.903]
# Epoch 10:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.827, v_num=0, train_loss_step=0.817, pixel_F1Score=0.217, pixel_AUROC=0.546, train_loss_epoch=0.870]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  94%|█████████▍| 32/34 [01:14<00:04,  2.33s/it, loss=0.827, v_num=0, train_loss_step=0.817, pixel_F1Score=0.217, pixel_AUROC=0.546, train_loss_epoch=0.870]
# Epoch 10:  97%|█████████▋| 33/34 [01:16<00:02,  2.32s/it, loss=0.827, v_num=0, train_loss_step=0.817, pixel_F1Score=0.217, pixel_AUROC=0.546, train_loss_epoch=0.870]
# Epoch 10: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.827, v_num=0, train_loss_step=0.817, pixel_F1Score=0.226, pixel_AUROC=0.618, train_loss_epoch=0.870]
# Epoch 11:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.793, v_num=0, train_loss_step=0.784, pixel_F1Score=0.226, pixel_AUROC=0.618, train_loss_epoch=0.835]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  94%|█████████▍| 32/34 [01:18<00:04,  2.47s/it, loss=0.793, v_num=0, train_loss_step=0.784, pixel_F1Score=0.226, pixel_AUROC=0.618, train_loss_epoch=0.835]
# Epoch 11:  97%|█████████▋| 33/34 [01:20<00:02,  2.45s/it, loss=0.793, v_num=0, train_loss_step=0.784, pixel_F1Score=0.226, pixel_AUROC=0.618, train_loss_epoch=0.835]
# Epoch 11: 100%|██████████| 34/34 [01:23<00:00,  2.45s/it, loss=0.793, v_num=0, train_loss_step=0.784, pixel_F1Score=0.259, pixel_AUROC=0.648, train_loss_epoch=0.835]
# Epoch 12:  91%|█████████ | 31/34 [01:08<00:06,  2.22s/it, loss=0.76, v_num=0, train_loss_step=0.732, pixel_F1Score=0.259, pixel_AUROC=0.648, train_loss_epoch=0.793]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  94%|█████████▍| 32/34 [01:14<00:04,  2.34s/it, loss=0.76, v_num=0, train_loss_step=0.732, pixel_F1Score=0.259, pixel_AUROC=0.648, train_loss_epoch=0.793]
# Epoch 12:  97%|█████████▋| 33/34 [01:16<00:02,  2.33s/it, loss=0.76, v_num=0, train_loss_step=0.732, pixel_F1Score=0.259, pixel_AUROC=0.648, train_loss_epoch=0.793]
# Epoch 12: 100%|██████████| 34/34 [01:19<00:00,  2.33s/it, loss=0.76, v_num=0, train_loss_step=0.732, pixel_F1Score=0.203, pixel_AUROC=0.643, train_loss_epoch=0.793]
# Epoch 13:  91%|█████████ | 31/34 [01:09<00:06,  2.25s/it, loss=0.741, v_num=0, train_loss_step=0.755, pixel_F1Score=0.203, pixel_AUROC=0.643, train_loss_epoch=0.765]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 13:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.741, v_num=0, train_loss_step=0.755, pixel_F1Score=0.203, pixel_AUROC=0.643, train_loss_epoch=0.765]
# Epoch 13:  97%|█████████▋| 33/34 [01:17<00:02,  2.35s/it, loss=0.741, v_num=0, train_loss_step=0.755, pixel_F1Score=0.203, pixel_AUROC=0.643, train_loss_epoch=0.765]
# Epoch 13: 100%|██████████| 34/34 [01:20<00:00,  2.35s/it, loss=0.741, v_num=0, train_loss_step=0.755, pixel_F1Score=0.265, pixel_AUROC=0.628, train_loss_epoch=0.765]
# Epoch 14:  91%|█████████ | 31/34 [01:09<00:06,  2.26s/it, loss=0.717, v_num=0, train_loss_step=0.690, pixel_F1Score=0.265, pixel_AUROC=0.628, train_loss_epoch=0.743]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 14:  94%|█████████▍| 32/34 [01:15<00:04,  2.37s/it, loss=0.717, v_num=0, train_loss_step=0.690, pixel_F1Score=0.265, pixel_AUROC=0.628, train_loss_epoch=0.743]
# Epoch 14:  97%|█████████▋| 33/34 [01:17<00:02,  2.36s/it, loss=0.717, v_num=0, train_loss_step=0.690, pixel_F1Score=0.265, pixel_AUROC=0.628, train_loss_epoch=0.743]
# Epoch 14: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, loss=0.717, v_num=0, train_loss_step=0.690, pixel_F1Score=0.277, pixel_AUROC=0.630, train_loss_epoch=0.743]
# Epoch 15:  91%|█████████ | 31/34 [01:07<00:06,  2.19s/it, loss=0.708, v_num=0, train_loss_step=0.697, pixel_F1Score=0.277, pixel_AUROC=0.630, train_loss_epoch=0.722]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 15:  94%|█████████▍| 32/34 [01:13<00:04,  2.30s/it, loss=0.708, v_num=0, train_loss_step=0.697, pixel_F1Score=0.277, pixel_AUROC=0.630, train_loss_epoch=0.722]
# Epoch 15:  97%|█████████▋| 33/34 [01:15<00:02,  2.29s/it, loss=0.708, v_num=0, train_loss_step=0.697, pixel_F1Score=0.277, pixel_AUROC=0.630, train_loss_epoch=0.722]
# Epoch 15: 100%|██████████| 34/34 [01:18<00:00,  2.30s/it, loss=0.708, v_num=0, train_loss_step=0.697, pixel_F1Score=0.235, pixel_AUROC=0.615, train_loss_epoch=0.722]
# Epoch 16:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.691, v_num=0, train_loss_step=0.659, pixel_F1Score=0.235, pixel_AUROC=0.615, train_loss_epoch=0.704]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 16:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.691, v_num=0, train_loss_step=0.659, pixel_F1Score=0.235, pixel_AUROC=0.615, train_loss_epoch=0.704]
# Epoch 16:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.691, v_num=0, train_loss_step=0.659, pixel_F1Score=0.235, pixel_AUROC=0.615, train_loss_epoch=0.704]
# Epoch 16: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.691, v_num=0, train_loss_step=0.659, pixel_F1Score=0.325, pixel_AUROC=0.708, train_loss_epoch=0.704]
# Epoch 17:  91%|█████████ | 31/34 [01:08<00:06,  2.22s/it, loss=0.68, v_num=0, train_loss_step=0.685, pixel_F1Score=0.325, pixel_AUROC=0.708, train_loss_epoch=0.691]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 17:  94%|█████████▍| 32/34 [01:14<00:04,  2.33s/it, loss=0.68, v_num=0, train_loss_step=0.685, pixel_F1Score=0.325, pixel_AUROC=0.708, train_loss_epoch=0.691]
# Epoch 17:  97%|█████████▋| 33/34 [01:16<00:02,  2.32s/it, loss=0.68, v_num=0, train_loss_step=0.685, pixel_F1Score=0.325, pixel_AUROC=0.708, train_loss_epoch=0.691]
# Epoch 17: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.68, v_num=0, train_loss_step=0.685, pixel_F1Score=0.217, pixel_AUROC=0.640, train_loss_epoch=0.691]
# Epoch 18:  91%|█████████ | 31/34 [01:07<00:06,  2.18s/it, loss=0.662, v_num=0, train_loss_step=0.666, pixel_F1Score=0.217, pixel_AUROC=0.640, train_loss_epoch=0.680]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 18:  94%|█████████▍| 32/34 [01:13<00:04,  2.30s/it, loss=0.662, v_num=0, train_loss_step=0.666, pixel_F1Score=0.217, pixel_AUROC=0.640, train_loss_epoch=0.680]
# Epoch 18:  97%|█████████▋| 33/34 [01:15<00:02,  2.29s/it, loss=0.662, v_num=0, train_loss_step=0.666, pixel_F1Score=0.217, pixel_AUROC=0.640, train_loss_epoch=0.680]
# Epoch 18: 100%|██████████| 34/34 [01:18<00:00,  2.29s/it, loss=0.662, v_num=0, train_loss_step=0.666, pixel_F1Score=0.237, pixel_AUROC=0.622, train_loss_epoch=0.680]
# Epoch 19:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.644, v_num=0, train_loss_step=0.654, pixel_F1Score=0.237, pixel_AUROC=0.622, train_loss_epoch=0.662]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 19:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.644, v_num=0, train_loss_step=0.654, pixel_F1Score=0.237, pixel_AUROC=0.622, train_loss_epoch=0.662]
# Epoch 19:  97%|█████████▋| 33/34 [01:17<00:02,  2.35s/it, loss=0.644, v_num=0, train_loss_step=0.654, pixel_F1Score=0.237, pixel_AUROC=0.622, train_loss_epoch=0.662]
# Epoch 19: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, loss=0.644, v_num=0, train_loss_step=0.654, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.662]
# Epoch 20:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.626, v_num=0, train_loss_step=0.642, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.648]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 20:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.626, v_num=0, train_loss_step=0.642, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.648]
# Epoch 20:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.626, v_num=0, train_loss_step=0.642, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.648]
# Epoch 20: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.626, v_num=0, train_loss_step=0.642, pixel_F1Score=0.214, pixel_AUROC=0.662, train_loss_epoch=0.648]
# Epoch 21:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.625, v_num=0, train_loss_step=0.669, pixel_F1Score=0.214, pixel_AUROC=0.662, train_loss_epoch=0.628]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 21:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.625, v_num=0, train_loss_step=0.669, pixel_F1Score=0.214, pixel_AUROC=0.662, train_loss_epoch=0.628]
# Epoch 21:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.625, v_num=0, train_loss_step=0.669, pixel_F1Score=0.214, pixel_AUROC=0.662, train_loss_epoch=0.628]
# Epoch 21: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.625, v_num=0, train_loss_step=0.669, pixel_F1Score=0.270, pixel_AUROC=0.653, train_loss_epoch=0.628]
# Epoch 22:  91%|█████████ | 31/34 [01:10<00:06,  2.26s/it, loss=0.62, v_num=0, train_loss_step=0.621, pixel_F1Score=0.270, pixel_AUROC=0.653, train_loss_epoch=0.624]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 22:  94%|█████████▍| 32/34 [01:15<00:04,  2.37s/it, loss=0.62, v_num=0, train_loss_step=0.621, pixel_F1Score=0.270, pixel_AUROC=0.653, train_loss_epoch=0.624]
# Epoch 22:  97%|█████████▋| 33/34 [01:17<00:02,  2.36s/it, loss=0.62, v_num=0, train_loss_step=0.621, pixel_F1Score=0.270, pixel_AUROC=0.653, train_loss_epoch=0.624]
# Epoch 22: 100%|██████████| 34/34 [01:20<00:00,  2.37s/it, loss=0.62, v_num=0, train_loss_step=0.621, pixel_F1Score=0.257, pixel_AUROC=0.650, train_loss_epoch=0.624]
# Epoch 23:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.602, v_num=0, train_loss_step=0.627, pixel_F1Score=0.257, pixel_AUROC=0.650, train_loss_epoch=0.617]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 23:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.602, v_num=0, train_loss_step=0.627, pixel_F1Score=0.257, pixel_AUROC=0.650, train_loss_epoch=0.617]
# Epoch 23:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.602, v_num=0, train_loss_step=0.627, pixel_F1Score=0.257, pixel_AUROC=0.650, train_loss_epoch=0.617]
# Epoch 23: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.602, v_num=0, train_loss_step=0.627, pixel_F1Score=0.273, pixel_AUROC=0.682, train_loss_epoch=0.617]
# Epoch 24:  91%|█████████ | 31/34 [01:09<00:06,  2.25s/it, loss=0.59, v_num=0, train_loss_step=0.618, pixel_F1Score=0.273, pixel_AUROC=0.682, train_loss_epoch=0.602]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 24:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.59, v_num=0, train_loss_step=0.618, pixel_F1Score=0.273, pixel_AUROC=0.682, train_loss_epoch=0.602]
# Epoch 24:  97%|█████████▋| 33/34 [01:17<00:02,  2.35s/it, loss=0.59, v_num=0, train_loss_step=0.618, pixel_F1Score=0.273, pixel_AUROC=0.682, train_loss_epoch=0.602]
# Epoch 24: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, loss=0.59, v_num=0, train_loss_step=0.618, pixel_F1Score=0.294, pixel_AUROC=0.679, train_loss_epoch=0.602]
# Epoch 25:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.59, v_num=0, train_loss_step=0.556, pixel_F1Score=0.294, pixel_AUROC=0.679, train_loss_epoch=0.593]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 25:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.59, v_num=0, train_loss_step=0.556, pixel_F1Score=0.294, pixel_AUROC=0.679, train_loss_epoch=0.593]
# Epoch 25:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.59, v_num=0, train_loss_step=0.556, pixel_F1Score=0.294, pixel_AUROC=0.679, train_loss_epoch=0.593]
# Epoch 25: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.59, v_num=0, train_loss_step=0.556, pixel_F1Score=0.331, pixel_AUROC=0.720, train_loss_epoch=0.593]
# Epoch 26:  91%|█████████ | 31/34 [01:09<00:06,  2.25s/it, loss=0.576, v_num=0, train_loss_step=0.612, pixel_F1Score=0.331, pixel_AUROC=0.720, train_loss_epoch=0.589]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 26:  94%|█████████▍| 32/34 [01:15<00:04,  2.37s/it, loss=0.576, v_num=0, train_loss_step=0.612, pixel_F1Score=0.331, pixel_AUROC=0.720, train_loss_epoch=0.589]
# Epoch 26:  97%|█████████▋| 33/34 [01:17<00:02,  2.36s/it, loss=0.576, v_num=0, train_loss_step=0.612, pixel_F1Score=0.331, pixel_AUROC=0.720, train_loss_epoch=0.589]
# Epoch 26: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, loss=0.576, v_num=0, train_loss_step=0.612, pixel_F1Score=0.291, pixel_AUROC=0.709, train_loss_epoch=0.589]
# Epoch 27:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.576, v_num=0, train_loss_step=0.590, pixel_F1Score=0.291, pixel_AUROC=0.709, train_loss_epoch=0.576]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 27:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.576, v_num=0, train_loss_step=0.590, pixel_F1Score=0.291, pixel_AUROC=0.709, train_loss_epoch=0.576]
# Epoch 27:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.576, v_num=0, train_loss_step=0.590, pixel_F1Score=0.291, pixel_AUROC=0.709, train_loss_epoch=0.576]
# Epoch 27: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.576, v_num=0, train_loss_step=0.590, pixel_F1Score=0.365, pixel_AUROC=0.727, train_loss_epoch=0.576]
# Epoch 28:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.566, v_num=0, train_loss_step=0.553, pixel_F1Score=0.365, pixel_AUROC=0.727, train_loss_epoch=0.572]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 28:  94%|█████████▍| 32/34 [01:14<00:04,  2.34s/it, loss=0.566, v_num=0, train_loss_step=0.553, pixel_F1Score=0.365, pixel_AUROC=0.727, train_loss_epoch=0.572]
# Epoch 28:  97%|█████████▋| 33/34 [01:16<00:02,  2.33s/it, loss=0.566, v_num=0, train_loss_step=0.553, pixel_F1Score=0.365, pixel_AUROC=0.727, train_loss_epoch=0.572]
# Epoch 28: 100%|██████████| 34/34 [01:19<00:00,  2.33s/it, loss=0.566, v_num=0, train_loss_step=0.553, pixel_F1Score=0.275, pixel_AUROC=0.719, train_loss_epoch=0.572]
# Epoch 29:  91%|█████████ | 31/34 [01:08<00:06,  2.23s/it, loss=0.552, v_num=0, train_loss_step=0.581, pixel_F1Score=0.275, pixel_AUROC=0.719, train_loss_epoch=0.567]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 29:  94%|█████████▍| 32/34 [01:14<00:04,  2.34s/it, loss=0.552, v_num=0, train_loss_step=0.581, pixel_F1Score=0.275, pixel_AUROC=0.719, train_loss_epoch=0.567]
# Epoch 29:  97%|█████████▋| 33/34 [01:16<00:02,  2.33s/it, loss=0.552, v_num=0, train_loss_step=0.581, pixel_F1Score=0.275, pixel_AUROC=0.719, train_loss_epoch=0.567]
# Epoch 29: 100%|██████████| 34/34 [01:19<00:00,  2.33s/it, loss=0.552, v_num=0, train_loss_step=0.581, pixel_F1Score=0.252, pixel_AUROC=0.637, train_loss_epoch=0.567]
# Epoch 30:  91%|█████████ | 31/34 [01:07<00:06,  2.19s/it, loss=0.546, v_num=0, train_loss_step=0.543, pixel_F1Score=0.252, pixel_AUROC=0.637, train_loss_epoch=0.556]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 30:  94%|█████████▍| 32/34 [01:13<00:04,  2.30s/it, loss=0.546, v_num=0, train_loss_step=0.543, pixel_F1Score=0.252, pixel_AUROC=0.637, train_loss_epoch=0.556]
# Epoch 30:  97%|█████████▋| 33/34 [01:15<00:02,  2.29s/it, loss=0.546, v_num=0, train_loss_step=0.543, pixel_F1Score=0.252, pixel_AUROC=0.637, train_loss_epoch=0.556]
# Epoch 30: 100%|██████████| 34/34 [01:18<00:00,  2.30s/it, loss=0.546, v_num=0, train_loss_step=0.543, pixel_F1Score=0.246, pixel_AUROC=0.641, train_loss_epoch=0.556]
# Epoch 31:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.544, v_num=0, train_loss_step=0.553, pixel_F1Score=0.246, pixel_AUROC=0.641, train_loss_epoch=0.542]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 31:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.544, v_num=0, train_loss_step=0.553, pixel_F1Score=0.246, pixel_AUROC=0.641, train_loss_epoch=0.542]
# Epoch 31:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.544, v_num=0, train_loss_step=0.553, pixel_F1Score=0.246, pixel_AUROC=0.641, train_loss_epoch=0.542]
# Epoch 31: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, loss=0.544, v_num=0, train_loss_step=0.553, pixel_F1Score=0.222, pixel_AUROC=0.622, train_loss_epoch=0.542]
# Epoch 32:  91%|█████████ | 31/34 [01:08<00:06,  2.20s/it, loss=0.54, v_num=0, train_loss_step=0.494, pixel_F1Score=0.222, pixel_AUROC=0.622, train_loss_epoch=0.545]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 32:  94%|█████████▍| 32/34 [01:14<00:04,  2.32s/it, loss=0.54, v_num=0, train_loss_step=0.494, pixel_F1Score=0.222, pixel_AUROC=0.622, train_loss_epoch=0.545]
# Epoch 32:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.54, v_num=0, train_loss_step=0.494, pixel_F1Score=0.222, pixel_AUROC=0.622, train_loss_epoch=0.545]
# Epoch 32: 100%|██████████| 34/34 [01:18<00:00,  2.31s/it, loss=0.54, v_num=0, train_loss_step=0.494, pixel_F1Score=0.167, pixel_AUROC=0.624, train_loss_epoch=0.545]
# Epoch 33:  91%|█████████ | 31/34 [01:09<00:06,  2.25s/it, loss=0.548, v_num=0, train_loss_step=0.532, pixel_F1Score=0.167, pixel_AUROC=0.624, train_loss_epoch=0.540]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 33:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.548, v_num=0, train_loss_step=0.532, pixel_F1Score=0.167, pixel_AUROC=0.624, train_loss_epoch=0.540]
# Epoch 33:  97%|█████████▋| 33/34 [01:17<00:02,  2.35s/it, loss=0.548, v_num=0, train_loss_step=0.532, pixel_F1Score=0.167, pixel_AUROC=0.624, train_loss_epoch=0.540]
# Epoch 33: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, loss=0.548, v_num=0, train_loss_step=0.532, pixel_F1Score=0.224, pixel_AUROC=0.659, train_loss_epoch=0.540]
# Epoch 34:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.517, v_num=0, train_loss_step=0.531, pixel_F1Score=0.224, pixel_AUROC=0.659, train_loss_epoch=0.541]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 34:  94%|█████████▍| 32/34 [01:14<00:04,  2.33s/it, loss=0.517, v_num=0, train_loss_step=0.531, pixel_F1Score=0.224, pixel_AUROC=0.659, train_loss_epoch=0.541]
# Epoch 34:  97%|█████████▋| 33/34 [01:16<00:02,  2.32s/it, loss=0.517, v_num=0, train_loss_step=0.531, pixel_F1Score=0.224, pixel_AUROC=0.659, train_loss_epoch=0.541]
# Epoch 34: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.517, v_num=0, train_loss_step=0.531, pixel_F1Score=0.254, pixel_AUROC=0.654, train_loss_epoch=0.541]
# Epoch 35:  91%|█████████ | 31/34 [01:08<00:06,  2.20s/it, loss=0.528, v_num=0, train_loss_step=0.529, pixel_F1Score=0.254, pixel_AUROC=0.654, train_loss_epoch=0.522]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 35:  94%|█████████▍| 32/34 [01:14<00:04,  2.31s/it, loss=0.528, v_num=0, train_loss_step=0.529, pixel_F1Score=0.254, pixel_AUROC=0.654, train_loss_epoch=0.522]
# Epoch 35:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.528, v_num=0, train_loss_step=0.529, pixel_F1Score=0.254, pixel_AUROC=0.654, train_loss_epoch=0.522]
# Epoch 35: 100%|██████████| 34/34 [01:18<00:00,  2.31s/it, loss=0.528, v_num=0, train_loss_step=0.529, pixel_F1Score=0.290, pixel_AUROC=0.668, train_loss_epoch=0.522]
# Epoch 36:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.517, v_num=0, train_loss_step=0.545, pixel_F1Score=0.290, pixel_AUROC=0.668, train_loss_epoch=0.520]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 36:  94%|█████████▍| 32/34 [01:14<00:04,  2.32s/it, loss=0.517, v_num=0, train_loss_step=0.545, pixel_F1Score=0.290, pixel_AUROC=0.668, train_loss_epoch=0.520]
# Epoch 36:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.517, v_num=0, train_loss_step=0.545, pixel_F1Score=0.290, pixel_AUROC=0.668, train_loss_epoch=0.520]
# Epoch 36: 100%|██████████| 34/34 [01:18<00:00,  2.31s/it, loss=0.517, v_num=0, train_loss_step=0.545, pixel_F1Score=0.284, pixel_AUROC=0.692, train_loss_epoch=0.520]
# Epoch 37:  91%|█████████ | 31/34 [01:08<00:06,  2.20s/it, loss=0.515, v_num=0, train_loss_step=0.502, pixel_F1Score=0.284, pixel_AUROC=0.692, train_loss_epoch=0.516]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 37:  94%|█████████▍| 32/34 [01:14<00:04,  2.32s/it, loss=0.515, v_num=0, train_loss_step=0.502, pixel_F1Score=0.284, pixel_AUROC=0.692, train_loss_epoch=0.516]
# Epoch 37:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.515, v_num=0, train_loss_step=0.502, pixel_F1Score=0.284, pixel_AUROC=0.692, train_loss_epoch=0.516]
# Epoch 37: 100%|██████████| 34/34 [01:18<00:00,  2.31s/it, loss=0.515, v_num=0, train_loss_step=0.502, pixel_F1Score=0.204, pixel_AUROC=0.565, train_loss_epoch=0.516]
# Epoch 38:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.512, v_num=0, train_loss_step=0.579, pixel_F1Score=0.204, pixel_AUROC=0.565, train_loss_epoch=0.519]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 38:  94%|█████████▍| 32/34 [01:14<00:04,  2.33s/it, loss=0.512, v_num=0, train_loss_step=0.579, pixel_F1Score=0.204, pixel_AUROC=0.565, train_loss_epoch=0.519]
# Epoch 38:  97%|█████████▋| 33/34 [01:16<00:02,  2.32s/it, loss=0.512, v_num=0, train_loss_step=0.579, pixel_F1Score=0.204, pixel_AUROC=0.565, train_loss_epoch=0.519]
# Epoch 38: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.512, v_num=0, train_loss_step=0.579, pixel_F1Score=0.216, pixel_AUROC=0.618, train_loss_epoch=0.519]
# Epoch 39:  91%|█████████ | 31/34 [01:09<00:06,  2.23s/it, loss=0.513, v_num=0, train_loss_step=0.508, pixel_F1Score=0.216, pixel_AUROC=0.618, train_loss_epoch=0.508]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 39:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.513, v_num=0, train_loss_step=0.508, pixel_F1Score=0.216, pixel_AUROC=0.618, train_loss_epoch=0.508]
# Epoch 39:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.513, v_num=0, train_loss_step=0.508, pixel_F1Score=0.216, pixel_AUROC=0.618, train_loss_epoch=0.508]
# Epoch 39: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.513, v_num=0, train_loss_step=0.508, pixel_F1Score=0.232, pixel_AUROC=0.607, train_loss_epoch=0.508]
# Epoch 40:  91%|█████████ | 31/34 [01:09<00:06,  2.25s/it, loss=0.497, v_num=0, train_loss_step=0.477, pixel_F1Score=0.232, pixel_AUROC=0.607, train_loss_epoch=0.510]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 40:  94%|█████████▍| 32/34 [01:15<00:04,  2.37s/it, loss=0.497, v_num=0, train_loss_step=0.477, pixel_F1Score=0.232, pixel_AUROC=0.607, train_loss_epoch=0.510]
# Epoch 40:  97%|█████████▋| 33/34 [01:17<00:02,  2.36s/it, loss=0.497, v_num=0, train_loss_step=0.477, pixel_F1Score=0.232, pixel_AUROC=0.607, train_loss_epoch=0.510]
# Epoch 40: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, loss=0.497, v_num=0, train_loss_step=0.477, pixel_F1Score=0.222, pixel_AUROC=0.630, train_loss_epoch=0.510]
# Epoch 41:  91%|█████████ | 31/34 [01:09<00:06,  2.26s/it, loss=0.498, v_num=0, train_loss_step=0.480, pixel_F1Score=0.222, pixel_AUROC=0.630, train_loss_epoch=0.491]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 41:  94%|█████████▍| 32/34 [01:15<00:04,  2.37s/it, loss=0.498, v_num=0, train_loss_step=0.480, pixel_F1Score=0.222, pixel_AUROC=0.630, train_loss_epoch=0.491]
# Epoch 41:  97%|█████████▋| 33/34 [01:17<00:02,  2.36s/it, loss=0.498, v_num=0, train_loss_step=0.480, pixel_F1Score=0.222, pixel_AUROC=0.630, train_loss_epoch=0.491]
# Epoch 41: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, loss=0.498, v_num=0, train_loss_step=0.480, pixel_F1Score=0.238, pixel_AUROC=0.625, train_loss_epoch=0.491]
# Epoch 42:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.491, v_num=0, train_loss_step=0.522, pixel_F1Score=0.238, pixel_AUROC=0.625, train_loss_epoch=0.499]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 42:  94%|█████████▍| 32/34 [01:15<00:04,  2.35s/it, loss=0.491, v_num=0, train_loss_step=0.522, pixel_F1Score=0.238, pixel_AUROC=0.625, train_loss_epoch=0.499]
# Epoch 42:  97%|█████████▋| 33/34 [01:17<00:02,  2.34s/it, loss=0.491, v_num=0, train_loss_step=0.522, pixel_F1Score=0.238, pixel_AUROC=0.625, train_loss_epoch=0.499]
# Epoch 42: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, loss=0.491, v_num=0, train_loss_step=0.522, pixel_F1Score=0.258, pixel_AUROC=0.635, train_loss_epoch=0.499]
# Epoch 43:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.493, v_num=0, train_loss_step=0.450, pixel_F1Score=0.258, pixel_AUROC=0.635, train_loss_epoch=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 43:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.493, v_num=0, train_loss_step=0.450, pixel_F1Score=0.258, pixel_AUROC=0.635, train_loss_epoch=0.496]
# Epoch 43:  97%|█████████▋| 33/34 [01:17<00:02,  2.35s/it, loss=0.493, v_num=0, train_loss_step=0.450, pixel_F1Score=0.258, pixel_AUROC=0.635, train_loss_epoch=0.496]
# Epoch 43: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, loss=0.493, v_num=0, train_loss_step=0.450, pixel_F1Score=0.294, pixel_AUROC=0.662, train_loss_epoch=0.496]
# Epoch 44:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.475, v_num=0, train_loss_step=0.451, pixel_F1Score=0.294, pixel_AUROC=0.662, train_loss_epoch=0.486]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 44:  94%|█████████▍| 32/34 [01:14<00:04,  2.32s/it, loss=0.475, v_num=0, train_loss_step=0.451, pixel_F1Score=0.294, pixel_AUROC=0.662, train_loss_epoch=0.486]
# Epoch 44:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.475, v_num=0, train_loss_step=0.451, pixel_F1Score=0.294, pixel_AUROC=0.662, train_loss_epoch=0.486]
# Epoch 44: 100%|██████████| 34/34 [01:18<00:00,  2.31s/it, loss=0.475, v_num=0, train_loss_step=0.451, pixel_F1Score=0.246, pixel_AUROC=0.616, train_loss_epoch=0.486]
# Epoch 45:  91%|█████████ | 31/34 [01:08<00:06,  2.21s/it, loss=0.493, v_num=0, train_loss_step=0.528, pixel_F1Score=0.246, pixel_AUROC=0.616, train_loss_epoch=0.481]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 45:  94%|█████████▍| 32/34 [01:14<00:04,  2.32s/it, loss=0.493, v_num=0, train_loss_step=0.528, pixel_F1Score=0.246, pixel_AUROC=0.616, train_loss_epoch=0.481]
# Epoch 45:  97%|█████████▋| 33/34 [01:16<00:02,  2.31s/it, loss=0.493, v_num=0, train_loss_step=0.528, pixel_F1Score=0.246, pixel_AUROC=0.616, train_loss_epoch=0.481]
# Epoch 45: 100%|██████████| 34/34 [01:18<00:00,  2.32s/it, loss=0.493, v_num=0, train_loss_step=0.528, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.481]
# Epoch 46:  91%|█████████ | 31/34 [01:09<00:06,  2.24s/it, loss=0.49, v_num=0, train_loss_step=0.518, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.490]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 46:  94%|█████████▍| 32/34 [01:15<00:04,  2.36s/it, loss=0.49, v_num=0, train_loss_step=0.518, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.490]
# Epoch 46:  97%|█████████▋| 33/34 [01:17<00:02,  2.35s/it, loss=0.49, v_num=0, train_loss_step=0.518, pixel_F1Score=0.245, pixel_AUROC=0.663, train_loss_epoch=0.490]
# Epoch 46: 100%|██████████| 34/34 [01:20<00:00,  2.38s/it, loss=0.49, v_num=0, train_loss_step=0.518, pixel_F1Score=0.246, pixel_AUROC=0.653, train_loss_epoch=0.490]
# Epoch 47:  91%|█████████ | 31/34 [01:10<00:06,  2.27s/it, loss=0.471, v_num=0, train_loss_step=0.465, pixel_F1Score=0.246, pixel_AUROC=0.653, train_loss_epoch=0.486]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 47:  94%|█████████▍| 32/34 [01:16<00:04,  2.38s/it, loss=0.471, v_num=0, train_loss_step=0.465, pixel_F1Score=0.246, pixel_AUROC=0.653, train_loss_epoch=0.486]
# Epoch 47:  97%|█████████▋| 33/34 [01:18<00:02,  2.37s/it, loss=0.471, v_num=0, train_loss_step=0.465, pixel_F1Score=0.246, pixel_AUROC=0.653, train_loss_epoch=0.486]
# Epoch 47: 100%|██████████| 34/34 [01:20<00:00,  2.37s/it, loss=0.471, v_num=0, train_loss_step=0.465, pixel_F1Score=0.248, pixel_AUROC=0.625, train_loss_epoch=0.486]
# Epoch 47: 100%|██████████| 34/34 [01:23<00:00,  2.45s/it, loss=0.471, v_num=0, train_loss_step=0.465, pixel_F1Score=0.248, pixel_AUROC=0.625, train_loss_epoch=0.473]

# %% [markdown]
# ## Validation

# %%
# load best model from checkpoint before evaluating
load_model_callback = LoadModelCallback(weights_path=trainer.checkpoint_callback.best_model_path)
trainer.callbacks.insert(0, load_model_callback)
test_results = trainer.test(model=model, datamodule=datamodule)
# Out:
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: EarlyStopping
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 2/2 [00:19<00:00,  9.56s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        image_AUROC          0.7527778148651123
#       image_F1Score         0.8169013857841492
#        pixel_AUROC          0.8907908201217651
#       pixel_F1Score         0.20489656925201416
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Inference

# %%
#load a test images
image_path = root_directory / "test_images/000.png"
image = read_image(path=image_path)
plt.imshow(image)
normalization = InputNormalizationMethod(config.dataset.normalization)
transform_config = config.dataset.transform_config.eval if "transform_config" in config.dataset.keys() else None
transform = get_transforms(
        config=transform_config, image_size=tuple(config.dataset.image_size), center_crop=config.dataset.get("center_crop"), normalization=normalization
    )

##apply transformation on the input image
dataset = InferenceDataset(
        image_path, image_size=tuple(config.dataset.image_size), transform=transform  # type: ignore
    )
dataloader = DataLoader(dataset)

# %%
output_path = Path(config["project"]["path"])
print(output_path)
pytorch_model_path = output_path / "weights" / "lightning" / "model.ckpt"
# Out:
# /ssd003/projects/aieng/public/anomaly_detection_models/MVtec/draem/mvtec/bottle/run

# %%
# generate predictions
predictions = trainer.predict(model=model, dataloaders=[dataloader])[0]

print(predictions.keys())


print(
    f'Image Shape: {predictions["image"].shape},\n'
    'Anomaly Map Shape: {predictions["anomaly_maps"].shape}, \n'
    'Predicted Mask Shape: {predictions["pred_masks"].shape}'
)
# Out:
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: EarlyStopping
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# dict_keys(['image', 'image_path', 'anomaly_maps', 'pred_scores', 'pred_labels', 'pred_masks', 'pred_boxes', 'box_scores', 'box_labels'])
# Image Shape: torch.Size([1, 3, 256, 256]),
# Anomaly Map Shape: {predictions["anomaly_maps"].shape},
# Predicted Mask Shape: {predictions["pred_masks"].shape}

# %%
image = predictions["image"][0]
image = Denormalize()(image)
print(f"Image Shape: {image.shape}\n Min Pixel: {image.min()} \n Max Pixel: {image.max()}")

plt.imshow(image)
# Out:
# Image Shape: (256, 256, 3)
#  Min Pixel: 29
#  Max Pixel: 255

# %% [markdown]
# ## Anomaly Map
#
# The second output of the predictions is the anomaly map. As can be seen above, it's also a torch tensor and of size torch.Size([1, 1, 256, 256]). We therefore need to convert it to numpy and squeeze the dimensions to make it 256x256 output to visualize.

# %%
anomaly_map = predictions["anomaly_maps"][0]
anomaly_map = anomaly_map.cpu().numpy().squeeze()
plt.imshow(anomaly_map)

# %%
heat_map = superimpose_anomaly_map(anomaly_map=anomaly_map, image=image, normalize=True)
plt.imshow(heat_map)

# %%
pred_score = predictions["pred_scores"][0]
pred_labels = predictions["pred_labels"][0]
print(pred_score, pred_labels)
# Out:
# tensor(0.6632) tensor(True)

# %%
pred_masks = predictions["pred_masks"][0].squeeze().cpu().numpy()
plt.imshow(pred_masks)

# %% [markdown]
# ## Model - CFA
#
# In this part, we'll be using [CFA: Coupled-Hypersphere-Based Feature Adaptation for Target-Oriented Anomaly Localization](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9839549). Now, let's get their config paths from the respected folders.

# %% [markdown]
# ## CFA Structure
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1P5CmWbqx9_Xb9-P-D_38A02L5e0qOKDg" width="100%" style="float:center;">
# </center>

# %% [markdown]
# ## CFA _ Feature Extraction and Training Path
#
# *   Inferring samples of the target dataset based on a pre-trained CNN with a large dataset, that is, a biased CNN. Since the feature maps sampled at each depth of CNN have different spatial resolutions, they are interpolated to have the same resolution and then concatenated.
# *   As a result, patch features $\mathcal{F} \in \mathbb{R}^{D \times H \times W}$ are generated. H and W mean the height and width of the largest features map, respectively and D indicates the sum of dimensions of the sampled feature maps.patch feature can be considered as semantic information at the pixel location.
# *   Used ResNet18 / Wide ResNet-50 as frozen CNN part.
# * Patch Descriptor: An auxiliary network with learnable parameters which converts patch features into target oriented features.
# * Memory Bank: Storing memorized features. Understanding normal features.
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1HTChBa68iWqaNdwnGBmk42DAi5V836Pn" width="600" aligh="center">
# </center>

# %% [markdown]
# ## CFA _ Memory Bank Compression
#
# * Transfer learning through the proposed CFA requires a memory bank for effective adaptation to the target dataset.
#
# * First, an initial memory bank $\mathcal{C}_0$ is constructed by applying $\mathrm{K}$-means clustering to all $\phi_0\left(\mathbf{p}_{t \in\{1, \ldots, T\}}\right)$ obtained from the first normal samples $\mathbf{x}_0$ of the train set $\mathcal{X}$. The process of updating the memory bank after $\mathcal{C}_0$ is as follows:
# * Infer the $i$-th normal sample $\mathbf{x}_i$ and search for the set of nearest patch features $\mathcal{C}_i^{N N}$ from the $i$-1th memory bank $\mathcal{C}_{i-1}$.
# * Next, the $i$-th memory bank of the next state $\mathcal{C}_i$ is calculated by exponential moving average (EMA) of $\mathcal{C}_i^{N N}$ and $\mathcal{C}_{i-1}$.
# * The final memory bank $\mathcal{C}$ is obtained by repeating the above process $|\mathcal{X}|$ times for all normal samples of the train set.
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1Se3xKggBLJMpWgwIwnJuDSUVh4EyqVta" width="600" aligh="center">
# </center>

# %% [markdown]
# ## CFA _ Attraction Loss Function
#
# $$
# \mathcal{L}_{a t t}=\frac{1}{T K} \sum_{t=1}^T \sum_{k=1}^K \max \left\{0, \mathcal{D}\left(\phi\left(\mathbf{p}_t\right), \mathbf{c}_t^k\right)-r^2\right\}
# $$
#
# * ${T}:\text{Number of total patch features}$
# * ${K}:\text{Number of nearest neighbors}$
# * ${D(a,b)}:\text{Euclidean distance between a and b}$
# * $\phi\left(\mathbf{p}_t\right): \text{Patch Descriptor}$
# * ${c}: \text{Centers}$
# * ${r}: \text{Radius}$
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1-obaxof5sIbeV1k7tV7c86oYRUXEsEg6" width="400" aligh="center">
# </center>

# %% [markdown]
# ## CFA _ Repel Loss Function
#
#
# $$
# \mathcal{L}_{\text {rep }}=\frac{1}{T J} \sum_{t=1}^T \sum_{j=1}^J \max \left\{0, r^2-\mathcal{D}\left(\phi\left(\mathbf{p}_t\right), \mathbf{c}_t^j\right)-\alpha\right\}
# $$
#
#
# * ${T}:\text{Number of total patch features}$
# * ${J}:\text{Total numebr of hard negative features}$
# * ${D(a,b)}:\text{Euclidean distance between a and b}$
# * $\phi\left(\mathbf{p}_t\right): \text{Patch Descriptor}$
# * ${c}: \text{Centers}$
# * ${r}: \text{Radius}$
# * ${\alpha}: \text{is used to control the balance between } \mathcal{L}_{\text {att }} \text{and } \mathcal{L}_{\text {rep }}$
#
# $$
# \mathcal{L}_{C F A}=\mathcal{L}_{a t t}+\mathcal{L}_{r e p}
# $$
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1-obaxof5sIbeV1k7tV7c86oYRUXEsEg6" width="400" aligh="center">
# </center>

# %% [markdown]
# ## CFA _ Scoring Function
#
# * means the minimum distance between patch descriptor φ(pt) and the memorized features C.
#
#
# $$
# \mathcal{S}_t=\min _k \mathcal{D}\left(\phi\left(\mathbf{p}_t\right), \mathbf{c}_t^k\right)
# $$
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=10GRUtPgnI5m5NlY2TV2D9Qdsubndv9Ap" width="300" aligh="center">
# </center>

# %% [markdown]
# ## CFA _ Time Complexity
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1pPgZvk2EQ8QDtr8bqGCNC3tmmSfGDPzu" width="500" aligh="center">
# </center>

# %% [markdown]
# ## CFA _ Results
# * AUROC : ROC is a probability curve and AUC represents the degree or measure of separability. It tells how much the model is capable of distinguishing between classes. Higher the AUC, the better the model is at predicting 0 classes as 0 and 1 classes as 1
# * I-AUROC: Image level AUROC
# * P-AUROC: Pixel Level AUROC
# * CFA++: Refers to a case that ensembles the results when using cropped images and using only resized samples.
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1cnSfMrtU4aEyfRyx6zCOFOXvCKDYDOf7" width="900" aligh="center">
# </center>

# %% [markdown]
# ## Configuration
#
# In this demonstration, we will work with [CFA](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9839549) model. Let's take a quick look at its config file.
# We control various parameters in the config file:
#
# **input data path** | **Dataset Category** | **Batch Sizes** | **Input Image size** | **# of Epochs** | **Saving Path**

# %%
MODEL = "cfa" # choosing the model 
CONFIG_PATH = root_directory / f"src/anomalib/models/{MODEL}/config.yaml" # detailed configs loaded from this file
print(CONFIG_PATH)
# Out:
# /ssd003/home/mpourreza/Projects/MVTec/anomalib/src/anomalib/models/cfa/config.yaml

# %% [markdown]
# We could use [get_configurable_parameter](https://github.com/openvinotoolkit/anomalib/blob/main/anomalib/config/config.py#L114) function to read the configs from the path and return them in a dictionary. We use the default config file that comes with CFA implementation, which uses defined path as the path to the dataset. We need to overwrite this after loading the config.

# %%
# pass the config file to model, callbacks and datamodule
config = get_configurable_parameters(config_path=CONFIG_PATH)
print(config.dataset.category)
config.dataset.category = "bottle" # Choosing the classes from MVTec classes
# Out:
# wood

# %% [markdown]
# **Download MVTEC Dataset**
#
# The provided source code initializes a data module using a given configuration, prepares the data by downloading the dataset if it's not already present in the specified root directory, and sets up the data module by creating train/validation/test/prediction sets. It then retrieves a batch of data from the validation data loader and prints the keys of the data dictionary to examine the available data fields.

# %%
datamodule = get_datamodule(config)
datamodule.prepare_data()  # Downloads the dataset if it's not in the specified `root` directory
datamodule.setup()  # Create train/val/test/prediction sets.

i, data = next(enumerate(datamodule.val_dataloader()))
print(data.keys())
# Out:
# dict_keys(['image_path', 'label', 'image', 'mask_path', 'mask'])

# %% [markdown]
# ## Mask
#
#
# In the context of the MVTEC test dataset, the "mask" refers to an additional array or image that accompanies each input image. The purpose of the mask is to provide annotations or labels indicating the regions within the image that contain anomalies or defects. The mask is typically binary, where the anomaly regions are marked as foreground (non-zero values) and the normal regions are marked as background (zero values).
#
# Let's check the shapes of the input images and masks.

# %%
print(data["image"].shape, data["mask"].shape)
# Out:
# torch.Size([4, 3, 224, 224]) torch.Size([4, 224, 224])

# %% [markdown]
# We could now visualize a normal and abnormal sample from the validation set.

# %%
def show_image_and_mask(sample: dict[str, Any], index: int) -> Image:
    """
    Display an image and its corresponding mask side by side.

    Args:
        sample (dict[str, Any]): A dictionary containing the image and mask arrays.
        index (int): The index of the specific image and mask to display.

    Returns:
        Image: The concatenated image and mask as a PIL Image object.
    """
    img = ToPILImage()(Denormalize()(sample["image"][index].clone()))
    msk = ToPILImage()(sample["mask"][index]).convert("RGB")

    return Image.fromarray(np.hstack((np.array(img), np.array(msk))))


# Visualize an image with a mask
show_image_and_mask(data, index=0)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224>

# %% [markdown]
# ## Train - Prepare Model and Callbacks
#
# Now, the config file is updated as we want. We can now start model training with it. Here we will be using `datamodule`, `model` and `callbacks` to train the model. Callbacks are self-contained objects, which contains non-essential logic. This way we could inject as many callbacks as possible such as ModelLoading, Timer, Metrics, Normalization and Visualization
#
# In addition to the training, we would like to perform inference using PyTorch model. Therefore we will set the export configuration to "torch" so that anomalib would export the trained model to the .cpkt format.

# %%
# Set the export-mode to Torch to create the torch model.
config.optimization.export_mode = "torch"

# Get the model and callbacks / Download the wide_resnet50 from pytorh hub
model = get_model(config)
callbacks = get_callbacks(config)
# Out:
# Downloading: "https://download.pytorch.org/models/wide_resnet50_2-95faca4d.pth" to /h/mpourreza/.cache/torch/hub/checkpoints/wide_resnet50_2-95faca4d.pth
# 100%|██████████| 132M/132M [00:01<00:00, 116MB/s]

# %%
# start training
trainer = Trainer(**config.trainer, callbacks=callbacks)
trainer.fit(model=model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                  | Type                     | Params
# -------------------------------------------------------------------
# 0 | image_threshold       | AnomalyScoreThreshold    | 0
# 1 | pixel_threshold       | AnomalyScoreThreshold    | 0
# 2 | model                 | CfaModel                 | 31.3 M
# 3 | loss                  | CfaLoss                  | 0
# 4 | image_metrics         | AnomalibMetricCollection | 0
# 5 | pixel_metrics         | AnomalibMetricCollection | 0
# 6 | normalization_metrics | MinMax                   | 0
# -------------------------------------------------------------------
# 31.3 M    Trainable params
# 0         Non-trainable params
# 31.3 M    Total params
# 125.169   Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   2%|▏         | 1/53 [00:10<09:27, 10.92s/it]
#   6%|▌         | 3/53 [00:11<02:24,  2.88s/it]
#   9%|▉         | 5/53 [00:11<01:08,  1.43s/it]
#  13%|█▎        | 7/53 [00:11<00:39,  1.18it/s]
#  19%|█▉        | 10/53 [00:11<00:20,  2.13it/s]
#  23%|██▎       | 12/53 [00:11<00:14,  2.91it/s]
#  26%|██▋       | 14/53 [00:11<00:10,  3.90it/s]
#  30%|███       | 16/53 [00:11<00:07,  5.11it/s]
#  34%|███▍      | 18/53 [00:11<00:05,  6.51it/s]
#  38%|███▊      | 20/53 [00:12<00:04,  7.92it/s]
#  42%|████▏     | 22/53 [00:12<00:03,  8.76it/s]
#  45%|████▌     | 24/53 [00:12<00:02, 10.15it/s]
#  49%|████▉     | 26/53 [00:12<00:02, 11.74it/s]
#  53%|█████▎    | 28/53 [00:12<00:01, 12.54it/s]
#  57%|█████▋    | 30/53 [00:12<00:01, 12.98it/s]
#  60%|██████    | 32/53 [00:12<00:01, 14.40it/s]
#  64%|██████▍   | 34/53 [00:12<00:01, 14.73it/s]
#  68%|██████▊   | 36/53 [00:13<00:01, 15.50it/s]
#  74%|███████▎  | 39/53 [00:13<00:00, 17.22it/s]
#  79%|███████▉  | 42/53 [00:13<00:00, 18.42it/s]
#  85%|████████▍ | 45/53 [00:13<00:00, 19.31it/s]
#  91%|█████████ | 48/53 [00:13<00:00, 19.82it/s]
# 100%|██████████| 53/53 [00:14<00:00,  3.77it/s]
# Epoch 0:   0%|          | 0/74 [00:00<?, ?it/s]
# Epoch 0:  72%|███████▏  | 53/74 [00:11<00:04,  4.53it/s, loss=627, v_num=6]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 0:  73%|███████▎  | 54/74 [00:13<00:05,  3.89it/s, loss=627, v_num=6]
# Epoch 0:  74%|███████▍  | 55/74 [00:14<00:04,  3.90it/s, loss=627, v_num=6]
# Epoch 0:  76%|███████▌  | 56/74 [00:14<00:04,  3.94it/s, loss=627, v_num=6]
# Epoch 0:  77%|███████▋  | 57/74 [00:14<00:04,  3.97it/s, loss=627, v_num=6]
# Epoch 0:  78%|███████▊  | 58/74 [00:14<00:03,  4.01it/s, loss=627, v_num=6]
# Epoch 0:  80%|███████▉  | 59/74 [00:14<00:03,  4.05it/s, loss=627, v_num=6]
# Epoch 0:  81%|████████  | 60/74 [00:14<00:03,  4.07it/s, loss=627, v_num=6]
# Epoch 0:  82%|████████▏ | 61/74 [00:14<00:03,  4.11it/s, loss=627, v_num=6]
# Epoch 0:  84%|████████▍ | 62/74 [00:14<00:02,  4.14it/s, loss=627, v_num=6]
# Epoch 0:  85%|████████▌ | 63/74 [00:15<00:02,  4.18it/s, loss=627, v_num=6]
# Epoch 0:  86%|████████▋ | 64/74 [00:15<00:02,  4.21it/s, loss=627, v_num=6]
# Epoch 0:  88%|████████▊ | 65/74 [00:15<00:02,  4.25it/s, loss=627, v_num=6]
# Epoch 0:  89%|████████▉ | 66/74 [00:15<00:01,  4.28it/s, loss=627, v_num=6]
# Epoch 0:  91%|█████████ | 67/74 [00:15<00:01,  4.32it/s, loss=627, v_num=6]
# Epoch 0:  92%|█████████▏| 68/74 [00:15<00:01,  4.35it/s, loss=627, v_num=6]
# Epoch 0:  93%|█████████▎| 69/74 [00:15<00:01,  4.39it/s, loss=627, v_num=6]
# Epoch 0:  95%|█████████▍| 70/74 [00:15<00:00,  4.41it/s, loss=627, v_num=6]
# Epoch 0:  96%|█████████▌| 71/74 [00:15<00:00,  4.45it/s, loss=627, v_num=6]
# Epoch 0:  97%|█████████▋| 72/74 [00:16<00:00,  4.47it/s, loss=627, v_num=6]
# Epoch 0:  99%|█████████▊| 73/74 [00:16<00:00,  4.51it/s, loss=627, v_num=6]
# Epoch 0: 100%|██████████| 74/74 [00:17<00:00,  4.17it/s, loss=627, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  72%|███████▏  | 53/74 [00:11<00:04,  4.80it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 1:  73%|███████▎  | 54/74 [00:13<00:05,  3.90it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  74%|███████▍  | 55/74 [00:14<00:04,  3.91it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  76%|███████▌  | 56/74 [00:14<00:04,  3.93it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  77%|███████▋  | 57/74 [00:14<00:04,  3.96it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  78%|███████▊  | 58/74 [00:14<00:04,  3.97it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  80%|███████▉  | 59/74 [00:14<00:03,  4.01it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  81%|████████  | 60/74 [00:14<00:03,  4.05it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  82%|████████▏ | 61/74 [00:14<00:03,  4.08it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  84%|████████▍ | 62/74 [00:15<00:02,  4.11it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  85%|████████▌ | 63/74 [00:15<00:02,  4.15it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  86%|████████▋ | 64/74 [00:15<00:02,  4.18it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  88%|████████▊ | 65/74 [00:15<00:02,  4.21it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  89%|████████▉ | 66/74 [00:15<00:01,  4.25it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  91%|█████████ | 67/74 [00:15<00:01,  4.28it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  92%|█████████▏| 68/74 [00:15<00:01,  4.31it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  93%|█████████▎| 69/74 [00:15<00:01,  4.35it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  95%|█████████▍| 70/74 [00:15<00:00,  4.38it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  96%|█████████▌| 71/74 [00:16<00:00,  4.41it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  97%|█████████▋| 72/74 [00:16<00:00,  4.44it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1:  99%|█████████▊| 73/74 [00:16<00:00,  4.47it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 1: 100%|██████████| 74/74 [00:17<00:00,  4.18it/s, loss=386, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  72%|███████▏  | 53/74 [00:11<00:04,  4.62it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 2:  73%|███████▎  | 54/74 [00:13<00:05,  3.90it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  74%|███████▍  | 55/74 [00:14<00:04,  3.88it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  76%|███████▌  | 56/74 [00:14<00:04,  3.90it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  77%|███████▋  | 57/74 [00:14<00:04,  3.94it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  78%|███████▊  | 58/74 [00:14<00:04,  3.97it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  80%|███████▉  | 59/74 [00:14<00:03,  4.01it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  81%|████████  | 60/74 [00:14<00:03,  4.05it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  82%|████████▏ | 61/74 [00:14<00:03,  4.09it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  84%|████████▍ | 62/74 [00:15<00:02,  4.12it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  85%|████████▌ | 63/74 [00:15<00:02,  4.15it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  86%|████████▋ | 64/74 [00:15<00:02,  4.19it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  88%|████████▊ | 65/74 [00:15<00:02,  4.22it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  89%|████████▉ | 66/74 [00:15<00:01,  4.25it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  91%|█████████ | 67/74 [00:15<00:01,  4.28it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  92%|█████████▏| 68/74 [00:15<00:01,  4.32it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  93%|█████████▎| 69/74 [00:15<00:01,  4.35it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  95%|█████████▍| 70/74 [00:15<00:00,  4.38it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  96%|█████████▌| 71/74 [00:16<00:00,  4.42it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  97%|█████████▋| 72/74 [00:16<00:00,  4.45it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2:  99%|█████████▊| 73/74 [00:16<00:00,  4.48it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 2: 100%|██████████| 74/74 [00:17<00:00,  4.23it/s, loss=337, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  72%|███████▏  | 53/74 [00:11<00:04,  4.77it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 3:  73%|███████▎  | 54/74 [00:13<00:05,  4.00it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  74%|███████▍  | 55/74 [00:13<00:04,  3.97it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  76%|███████▌  | 56/74 [00:14<00:04,  4.00it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  77%|███████▋  | 57/74 [00:14<00:04,  4.02it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  78%|███████▊  | 58/74 [00:14<00:03,  4.06it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  80%|███████▉  | 59/74 [00:14<00:03,  4.10it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  81%|████████  | 60/74 [00:14<00:03,  4.14it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  82%|████████▏ | 61/74 [00:14<00:03,  4.17it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  84%|████████▍ | 62/74 [00:14<00:02,  4.21it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  85%|████████▌ | 63/74 [00:14<00:02,  4.25it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  86%|████████▋ | 64/74 [00:14<00:02,  4.28it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  88%|████████▊ | 65/74 [00:15<00:02,  4.31it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  89%|████████▉ | 66/74 [00:15<00:01,  4.35it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  91%|█████████ | 67/74 [00:15<00:01,  4.38it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  92%|█████████▏| 68/74 [00:15<00:01,  4.42it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  93%|█████████▎| 69/74 [00:15<00:01,  4.45it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  95%|█████████▍| 70/74 [00:15<00:00,  4.48it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  96%|█████████▌| 71/74 [00:15<00:00,  4.52it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  97%|█████████▋| 72/74 [00:15<00:00,  4.55it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3:  99%|█████████▊| 73/74 [00:15<00:00,  4.58it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 3: 100%|██████████| 74/74 [00:17<00:00,  4.30it/s, loss=305, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  72%|███████▏  | 53/74 [00:11<00:04,  4.59it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 4:  73%|███████▎  | 54/74 [00:14<00:05,  3.84it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  74%|███████▍  | 55/74 [00:14<00:04,  3.83it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  76%|███████▌  | 56/74 [00:14<00:04,  3.86it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  77%|███████▋  | 57/74 [00:14<00:04,  3.89it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  78%|███████▊  | 58/74 [00:14<00:04,  3.92it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  80%|███████▉  | 59/74 [00:14<00:03,  3.96it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  81%|████████  | 60/74 [00:15<00:03,  3.99it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  82%|████████▏ | 61/74 [00:15<00:03,  4.03it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  84%|████████▍ | 62/74 [00:15<00:02,  4.07it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  85%|████████▌ | 63/74 [00:15<00:02,  4.10it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  86%|████████▋ | 64/74 [00:15<00:02,  4.14it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  88%|████████▊ | 65/74 [00:15<00:02,  4.17it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  89%|████████▉ | 66/74 [00:15<00:01,  4.20it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  91%|█████████ | 67/74 [00:15<00:01,  4.24it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  92%|█████████▏| 68/74 [00:15<00:01,  4.27it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  93%|█████████▎| 69/74 [00:16<00:01,  4.30it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  95%|█████████▍| 70/74 [00:16<00:00,  4.33it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  96%|█████████▌| 71/74 [00:16<00:00,  4.37it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  97%|█████████▋| 72/74 [00:16<00:00,  4.40it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4:  99%|█████████▊| 73/74 [00:16<00:00,  4.43it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 4: 100%|██████████| 74/74 [00:17<00:00,  4.18it/s, loss=281, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  72%|███████▏  | 53/74 [00:11<00:04,  4.56it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 5:  73%|███████▎  | 54/74 [00:13<00:05,  3.87it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  74%|███████▍  | 55/74 [00:14<00:04,  3.84it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  76%|███████▌  | 56/74 [00:14<00:04,  3.87it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  77%|███████▋  | 57/74 [00:14<00:04,  3.90it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  78%|███████▊  | 58/74 [00:14<00:04,  3.93it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  80%|███████▉  | 59/74 [00:14<00:03,  3.97it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  81%|████████  | 60/74 [00:14<00:03,  4.01it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  82%|████████▏ | 61/74 [00:15<00:03,  4.04it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  84%|████████▍ | 62/74 [00:15<00:02,  4.08it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  85%|████████▌ | 63/74 [00:15<00:02,  4.11it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  86%|████████▋ | 64/74 [00:15<00:02,  4.14it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  88%|████████▊ | 65/74 [00:15<00:02,  4.18it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  89%|████████▉ | 66/74 [00:15<00:01,  4.22it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  91%|█████████ | 67/74 [00:15<00:01,  4.25it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  92%|█████████▏| 68/74 [00:15<00:01,  4.28it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  93%|█████████▎| 69/74 [00:15<00:01,  4.31it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  95%|█████████▍| 70/74 [00:16<00:00,  4.35it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  96%|█████████▌| 71/74 [00:16<00:00,  4.38it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  97%|█████████▋| 72/74 [00:16<00:00,  4.41it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5:  99%|█████████▊| 73/74 [00:16<00:00,  4.44it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 5: 100%|██████████| 74/74 [00:17<00:00,  4.19it/s, loss=261, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  72%|███████▏  | 53/74 [00:11<00:04,  4.44it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 6:  73%|███████▎  | 54/74 [00:14<00:05,  3.74it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  74%|███████▍  | 55/74 [00:14<00:05,  3.73it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  76%|███████▌  | 56/74 [00:14<00:04,  3.74it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  77%|███████▋  | 57/74 [00:15<00:04,  3.78it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  78%|███████▊  | 58/74 [00:15<00:04,  3.81it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  80%|███████▉  | 59/74 [00:15<00:03,  3.85it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  81%|████████  | 60/74 [00:15<00:03,  3.88it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  82%|████████▏ | 61/74 [00:15<00:03,  3.92it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  84%|████████▍ | 62/74 [00:15<00:03,  3.95it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  85%|████████▌ | 63/74 [00:15<00:02,  3.98it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  86%|████████▋ | 64/74 [00:15<00:02,  4.02it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  88%|████████▊ | 65/74 [00:16<00:02,  4.05it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  89%|████████▉ | 66/74 [00:16<00:01,  4.08it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  91%|█████████ | 67/74 [00:16<00:01,  4.12it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  92%|█████████▏| 68/74 [00:16<00:01,  4.15it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  93%|█████████▎| 69/74 [00:16<00:01,  4.18it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  95%|█████████▍| 70/74 [00:16<00:00,  4.21it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  96%|█████████▌| 71/74 [00:16<00:00,  4.24it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  97%|█████████▋| 72/74 [00:16<00:00,  4.28it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6:  99%|█████████▊| 73/74 [00:16<00:00,  4.31it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 6: 100%|██████████| 74/74 [00:18<00:00,  4.06it/s, loss=242, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  72%|███████▏  | 53/74 [00:11<00:04,  4.43it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 7:  73%|███████▎  | 54/74 [00:14<00:05,  3.76it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  74%|███████▍  | 55/74 [00:14<00:05,  3.74it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  76%|███████▌  | 56/74 [00:14<00:04,  3.74it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  77%|███████▋  | 57/74 [00:15<00:04,  3.75it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  78%|███████▊  | 58/74 [00:15<00:04,  3.78it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  80%|███████▉  | 59/74 [00:15<00:03,  3.81it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  81%|████████  | 60/74 [00:15<00:03,  3.85it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  82%|████████▏ | 61/74 [00:15<00:03,  3.88it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  84%|████████▍ | 62/74 [00:15<00:03,  3.92it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  85%|████████▌ | 63/74 [00:15<00:02,  3.95it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  86%|████████▋ | 64/74 [00:16<00:02,  3.98it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  88%|████████▊ | 65/74 [00:16<00:02,  4.02it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  89%|████████▉ | 66/74 [00:16<00:01,  4.05it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  91%|█████████ | 67/74 [00:16<00:01,  4.08it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  92%|█████████▏| 68/74 [00:16<00:01,  4.11it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  93%|█████████▎| 69/74 [00:16<00:01,  4.14it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  95%|█████████▍| 70/74 [00:16<00:00,  4.18it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  96%|█████████▌| 71/74 [00:16<00:00,  4.21it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  97%|█████████▋| 72/74 [00:16<00:00,  4.24it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7:  99%|█████████▊| 73/74 [00:17<00:00,  4.27it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 7: 100%|██████████| 74/74 [00:18<00:00,  4.03it/s, loss=228, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  72%|███████▏  | 53/74 [00:11<00:04,  4.42it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 8:  73%|███████▎  | 54/74 [00:14<00:05,  3.72it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  74%|███████▍  | 55/74 [00:14<00:05,  3.74it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  76%|███████▌  | 56/74 [00:14<00:04,  3.75it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  77%|███████▋  | 57/74 [00:15<00:04,  3.78it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  78%|███████▊  | 58/74 [00:15<00:04,  3.81it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  80%|███████▉  | 59/74 [00:15<00:03,  3.84it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  81%|████████  | 60/74 [00:15<00:03,  3.88it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  82%|████████▏ | 61/74 [00:15<00:03,  3.92it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  84%|████████▍ | 62/74 [00:15<00:03,  3.95it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  85%|████████▌ | 63/74 [00:15<00:02,  3.98it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  86%|████████▋ | 64/74 [00:15<00:02,  4.02it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  88%|████████▊ | 65/74 [00:16<00:02,  4.05it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  89%|████████▉ | 66/74 [00:16<00:01,  4.08it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  91%|█████████ | 67/74 [00:16<00:01,  4.12it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  92%|█████████▏| 68/74 [00:16<00:01,  4.15it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  93%|█████████▎| 69/74 [00:16<00:01,  4.18it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  95%|█████████▍| 70/74 [00:16<00:00,  4.21it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  96%|█████████▌| 71/74 [00:16<00:00,  4.24it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  97%|█████████▋| 72/74 [00:16<00:00,  4.27it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8:  99%|█████████▊| 73/74 [00:16<00:00,  4.30it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 8: 100%|██████████| 74/74 [00:18<00:00,  4.06it/s, loss=215, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  72%|███████▏  | 53/74 [00:12<00:04,  4.40it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/21 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch 9:  73%|███████▎  | 54/74 [00:14<00:05,  3.70it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  74%|███████▍  | 55/74 [00:14<00:05,  3.72it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  76%|███████▌  | 56/74 [00:14<00:04,  3.73it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  77%|███████▋  | 57/74 [00:15<00:04,  3.75it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  78%|███████▊  | 58/74 [00:15<00:04,  3.78it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  80%|███████▉  | 59/74 [00:15<00:03,  3.82it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  81%|████████  | 60/74 [00:15<00:03,  3.86it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  82%|████████▏ | 61/74 [00:15<00:03,  3.89it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  84%|████████▍ | 62/74 [00:15<00:03,  3.92it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  85%|████████▌ | 63/74 [00:15<00:02,  3.96it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  86%|████████▋ | 64/74 [00:16<00:02,  3.99it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  88%|████████▊ | 65/74 [00:16<00:02,  4.02it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  89%|████████▉ | 66/74 [00:16<00:01,  4.06it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  91%|█████████ | 67/74 [00:16<00:01,  4.09it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  92%|█████████▏| 68/74 [00:16<00:01,  4.13it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  93%|█████████▎| 69/74 [00:16<00:01,  4.16it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  95%|█████████▍| 70/74 [00:16<00:00,  4.19it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  96%|█████████▌| 71/74 [00:16<00:00,  4.22it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  97%|█████████▋| 72/74 [00:16<00:00,  4.25it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9:  99%|█████████▊| 73/74 [00:17<00:00,  4.28it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9: 100%|██████████| 74/74 [00:18<00:00,  4.04it/s, loss=207, v_num=6, pixel_AUROC=0.989]
# Epoch 9: 100%|██████████| 74/74 [00:20<00:00,  3.69it/s, loss=207, v_num=6, pixel_AUROC=0.989]

# %% [markdown]
# ## Validation

# %%
# load best model from checkpoint before evaluating
load_model_callback = LoadModelCallback(weights_path=trainer.checkpoint_callback.best_model_path)
trainer.callbacks.insert(0, load_model_callback)
test_results = trainer.test(model=model, datamodule=datamodule)
# Out:
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: EarlyStopping
# /ssd003/projects/aieng/public/anomaly_detection_models/MVtec/cfa/mvtec/bottle/run/weights/lightning/model.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 21/21 [00:31<00:00,  1.51s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        image_AUROC          0.9976190328598022
#        pixel_AUROC          0.9892481565475464
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### Inference
# Since we have a trained model, we could infer the model on an individual image or folder of images. Anomalib has an InferenceDataset to let you create an inference dataset. So let's try it.

# %%
# Load a Test Image
image_path = root_directory / "test_images/000.png"
image = read_image(path=image_path)
plt.imshow(image)

# Define normalization and transformation
normalization = InputNormalizationMethod(config.dataset.normalization)
transform_config = config.dataset.transform_config.eval if "transform_config" in config.dataset.keys() else None
transform = get_transforms(
        config=transform_config, image_size=tuple(config.dataset.image_size), center_crop=config.dataset.get("center_crop"), normalization=normalization
    )

# Apply transformation on the input image
dataset = InferenceDataset(
        image_path, image_size=tuple(config.dataset.image_size), transform=transform  # type: ignore
    )
dataloader = DataLoader(dataset)

# %% [markdown]
# ### Load the Pytorch Model
#
# By default, the output files are saved into predefined path in config file. Let's check where the pytorch model is stored.

# %%
output_path = Path(config["project"]["path"])
print(output_path)
# Out:
# /ssd003/projects/aieng/public/anomaly_detection_models/MVtec/cfa/mvtec/bottle/run

# %%
pytorch_model_path = output_path / "weights" / "lightning" / "model.ckpt"

# %% [markdown]
# predictions contain image, anomaly maps, predicted scores, labels and masks. These are all stored in a dictionary.
# We could check this by printing the prediction keys.

# %%
# generate predictions
predictions = trainer.predict(model=model, dataloaders=[dataloader])[0]

print(predictions.keys())


print(
    f'Image Shape: {predictions["image"].shape},\n'
    'Anomaly Map Shape: {predictions["anomaly_maps"].shape}, \n'
    'Predicted Mask Shape: {predictions["pred_masks"].shape}'
)
# Out:
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: EarlyStopping
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# dict_keys(['image', 'image_path', 'anomaly_maps', 'pred_scores', 'pred_labels', 'pred_masks', 'pred_boxes', 'box_scores', 'box_labels'])
# Image Shape: torch.Size([1, 3, 224, 224]),
# Anomaly Map Shape: {predictions["anomaly_maps"].shape},
# Predicted Mask Shape: {predictions["pred_masks"].shape}

# %% [markdown]
# ### Visualization
# To properly visualize the predictions, we will need to perform some post-processing operations.
#
# Let's post-process each output one by one. We could start with the image. Each image is a tensor and within (0, 1) range. To visualize it, we need to denormalize it to (0, 255) scale. Anomalib already has a class for this. Let's use it.

# %%
image = predictions["image"][0]
image = Denormalize()(image)
print(f"Image Shape: {image.shape}\n Min Pixel: {image.min()} \n Max Pixel: {image.max()}")

# Display the image
plt.imshow(image)
# Out:
# Image Shape: (224, 224, 3)
#  Min Pixel: 27
#  Max Pixel: 255

# %% [markdown]
# ## Anomaly Map
#
# The second output of the predictions is the anomaly map. As can be seen above, it's also a torch tensor and of size torch.Size([1, 1, 256, 256]). We therefore need to convert it to numpy and squeeze the dimensions to make it 256x256 output to visualize.

# %%
anomaly_map = predictions["anomaly_maps"][0]
anomaly_map = anomaly_map.cpu().numpy().squeeze()
plt.imshow(anomaly_map)

# %% [markdown]
# We could superimpose (overlay) the anomaly map on top of the original image to get a heat map. Anomalib has a built-in function to achieve this. Let's try it.

# %%
heat_map = superimpose_anomaly_map(anomaly_map=anomaly_map, image=image, normalize=True)
plt.imshow(heat_map) #plot heatmap

# %% [markdown]
# predictions also contains prediction scores and labels.

# %%
pred_score = predictions["pred_scores"][0]
pred_labels = predictions["pred_labels"][0]
print(pred_score, pred_labels)
# Out:
# tensor(0.7623) tensor(True)

# %% [markdown]
# The last part of the predictions is the mask that is predicted by the model. This is a boolean mask containing True/False for the abnormal/normal pixels, respectively.

# %%
pred_masks = predictions["pred_masks"][0].squeeze().cpu().numpy()
plt.imshow(pred_masks)

# %% [markdown]
# ## Further Reading
#
# * [Towards Total Recall in Industrial Anomaly Detection](https://openaccess.thecvf.com/content/CVPR2022/html/Roth_Towards_Total_Recall_in_Industrial_Anomaly_Detection_CVPR_2022_paper.html)
#
# * [PaDiM: a Patch Distribution Modeling Framework for Anomaly Detection and Localization
# ](https://arxiv.org/abs/2011.08785)
#
# * [SimpleNet: A Simple Network for Image Anomaly Detection and Localization](https://openaccess.thecvf.com/content/CVPR2023/html/Liu_SimpleNet_A_Simple_Network_for_Image_Anomaly_Detection_and_Localization_CVPR_2023_paper.html)

# %% [markdown]
# ## Gradio and Hugging Face
#
# We have created an anomaly detection model based on the CFA architecture trained on the MVTEC Test dataset. The CFA model is a deep learning-based approach that can identify anomalies or defects in various object and texture categories commonly encountered in industrial inspection tasks.
#
# Features:
# - Pretrained CFA model for anomaly detection
# - Interactive web-based demo using Gradio
# - Easy-to-use interface for uploading test images and obtaining anomaly predictions
# - Efficient inference with GPU support
# - Seamless integration with Hugging Face Spaces for model sharing and deployment
#
# Access the project's Hugging Face Spaces page at https://huggingface.co/spaces/masoudpz/cfa_mvtec_test.
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1mRLfZnf8xSR34Ee6Wq8XiZB1pyVvv5Xl
# " width="700" aligh="center">
# </center>
#
#
# ## Gradio Key Features
#
# * [Adding example inputs](https://gradio.app/key-features/#example-inputs)
# * [Passing custom error messages](https://gradio.app/key-features/#errors)
# * [Adding descriptive content](https://gradio.app/key-features/#descriptive-content)
# * [Setting up flagging](https://gradio.app/key-features/#flagging)
# * [Preprocessing and postprocessing](https://gradio.app/key-features/#preprocessing-and-postprocessing)
# * [Styling demos](https://gradio.app/key-features/#styling)
# * [Queuing users](https://gradio.app/key-features/#queuing)
# * [Iterative outputs](https://gradio.app/key-features/#iterative-outputs)
# * [Progress bars](https://gradio.app/key-features/#progress-bars)
# * [Batch functions](https://gradio.app/key-features/#batch-functions)
# * [Running on collaborative notebooks](https://gradio.app/key-features/#colab-notebooks)
# * [Caching Data and states](https://gradio.app/more-on-examples/#caching-examples)

# %% [markdown]
# ## References

# %% [markdown]
# 1. [CFA: Coupled-Hypersphere-Based Feature
# Adaptation for Target-Oriented
# Anomaly Localization](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9839549)
#
# 2. [DRÆM–Adiscriminativelytrainedreconstructionembeddingforsurface anomalydetection](https://openaccess.thecvf.com/content/ICCV2021/papers/Zavrtanik_DRAEM_-_A_Discriminatively_Trained_Reconstruction_Embedding_for_Surface_Anomaly_ICCV_2021_paper.pdf)
# 3. [PyOD Package](https://github.com/yzhao062/pyod)
# 4.[Anomlaib Package](https://github.com/openvinotoolkit/anomalib)
